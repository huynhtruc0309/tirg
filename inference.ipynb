# %%
import torch
import img_text_composition_models
from main import parse_opt, load_dataset
import test_retrieval

# %%
opt = parse_opt()
trainset, testset = load_dataset(opt)
embed_dim = 512

path = 'checkpoints/checkpoint_fashion200k.pth'
device = torch.device('cpu')
model = img_text_composition_models.TIRG(
        [t for t in trainset.get_all_texts()], embed_dim=embed_dim)
checkpoint = torch.load(path, map_location=device)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()
# Out:
# Reading dataset  fashion200k
# read dress_train_detect_all.txt
# read jacket_train_detect_all.txt
# read pants_train_detect_all.txt
# read skirt_train_detect_all.txt
# read top_train_detect_all.txt
# Fashion200k: 172049 images
# 53099 unique cations
# Modifiable images 106464
# read dress_test_detect_all.txt
# read jacket_test_detect_all.txt
# read pants_test_detect_all.txt
# read skirt_test_detect_all.txt
# read top_test_detect_all.txt
# Fashion200k: 29789 images
# trainset size: 172049
# testset size: 29789
# TIRG(
#   (normalization_layer): NormalizationLayer()
#   (soft_triplet_loss): TripletLoss()
#   (img_model): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
# ...

# %%
test_retrieval.test(opt, model, testset)
# Out:
#   0%|          | 31/33480 [00:00<02:28, 225.22it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-96c04278243c> in <module>
# ----> 1 test_retrieval.test(opt, model, testset)
#
# /media/huynhtruc0309/DATA/hcmus/thesis/code/tirg/test_retrieval.py in test(opt, model, testset)
#      40           imgs = [torch.from_numpy(d).float() for d in imgs] # đổi các ảnh từ dạng numpy sang tensor
#      41         imgs = torch.stack(imgs).float()
# ---> 42         # imgs = torch.autograd.Variable(imgs).cuda() # xếp chồng các ảnh nguồn lại
#      43         imgs = torch.autograd.Variable(imgs)
#      44         mods = [t for t in mods] # vb thay đổi thành một list
#
# ~/anaconda3/envs/truchlp/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     184             raise RuntimeError(
# ...

# %%
testset.get_test_queries()
# Out:
# [{'source_img_id': 520,
#   'source_caption': 'green resort maxi dress',
#   'target_caption': 'pink resort maxi dress',
#   'mod': {'str': 'replace green with pink'}},
#  {'source_img_id': 997,
#   'source_caption': 'pink printed chiffon gown',
#   'target_caption': 'pink printed silk gown',
#   'mod': {'str': 'replace chiffon with silk'}},
#  {'source_img_id': 1007,
#   'source_caption': 'blue off-the-shoulder lace sequin gown',
#   'target_caption': 'gold off-the-shoulder sequin lace gown',
#   'mod': {'str': 'replace blue with gold'}},
#  {'source_img_id': 1886,
#   'source_caption': 'multicolor printed crepe dress',
#   'target_caption': 'purple printed crepe dress',
#   'mod': {'str': 'replace multicolor with purple'}},
#  {'source_img_id': 1886,
#   'source_caption': 'multicolor printed crepe dress',
#   'target_caption': 'blue printed crepe dress',
#   'mod': {'str': 'replace multicolor with blue'}},
#  {'source_img_id': 4146,
# ...

# %%
# Out:
# Namespace(batch_size=32, comment='test_notebook', dataset='fashion200k', dataset_path='/media/huynhtruc0309/335274A52EB9F27F/hcmus/thesis/data/Fashion200k', embed_dim=512, f='/home/huynhtruc0309/.local/share/jupyter/runtime/kernel-88a3b63d-e524-4fd5-906a-fca8a6572550.json', learning_rate=0.01, learning_rate_decay_frequency=9999999, loader_num_workers=4, loss='soft_triplet', model='tirg', num_iters=210000, weight_decay=1e-06)
